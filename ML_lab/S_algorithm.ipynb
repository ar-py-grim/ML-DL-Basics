# %%
# Aim: Implement and demonstrate the FIND-S algorithm for finding the most specific hypothesis based on a given set of training data samples.
# Read the training data from a .csv file

import pandas as pd
import numpy as np
from copy import copy

# %%
data = pd.read_csv(r'Data.csv')
data
# Out:
#       Time Weather Temperature Company Humidity    Wind Goes
# 0  Morning   Sunny        Warm     Yes    Mild   Strong  Yes
# 1  Evening   Rainy        Cold      No    Mild   Normal   No
# 2  Morning   Sunny    Moderate     Yes   Normal  Normal  Yes
# 3  Evening   Sunny        Cold     Yes     High  Strong  Yes

# %%
# attribute column

data1= data.iloc[:,:-1]
data1 = np.array(data1)
data1
# Out:
# array([['Morning', 'Sunny', 'Warm', 'Yes', 'Mild ', 'Strong'],
#        ['Evening', 'Rainy', 'Cold', 'No', 'Mild ', 'Normal'],
#        ['Morning', 'Sunny', 'Moderate', 'Yes', 'Normal', 'Normal'],
#        ['Evening', 'Sunny', 'Cold', 'Yes', 'High', 'Strong']],
#       dtype=object)

# %%
# to extract target

target = data.iloc[:,-1:]
target = np.array(target)
print(target)
# Out:
# [['Yes']
#  ['No']
#  ['Yes']
#  ['Yes']]

# %%
h0 = data1[0]
h0
# Out:
# array(['Morning', 'Sunny', 'Warm', 'Yes', 'Mild ', 'Strong'], dtype=object)

# %%
cnt=0
for i,j in zip(data1,target):
    #print(i,j)
    if j==['No']:
        print(cnt)
        data1 = np.delete(data1,cnt,axis=0)
        target = np.delete(target,cnt,axis=0)
    else:
        cnt +=1

# print(target)
print(data1)
# Out:
# 1
# [['Morning' 'Sunny' 'Warm' 'Yes' 'Mild ' 'Strong']
#  ['Morning' 'Sunny' 'Moderate' 'Yes' 'Normal' 'Normal']
#  ['Evening' 'Sunny' 'Cold' 'Yes' 'High' 'Strong']]

# %%
h1 = []
for i,j in zip(data1[0],data1[1]):
    #print(i,j)
    if i!=j:
        h1.append('?')
    else:
        h1.append(i)
        
print(h1)
# Out:
# ['Morning', 'Sunny', '?', 'Yes', '?', '?']

# %%
h2 = []
for i,j in zip(data1[1],data1[2]):
    #print(i,j)
    if i!=j:
        h2.append('?')
    else:
        h2.append(i)
        
print(h2)
# Out:
# ['?', 'Sunny', '?', 'Yes', '?', '?']
