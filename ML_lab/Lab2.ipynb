# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'employees.csv')
data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
print(f"type: {type(data)}")
# Out:
# type: <class 'pandas.core.frame.DataFrame'>

# %%
data.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
money = data['Salary']
money
# Out:
# 0       97308
# 1       61933
# 2      130590
# 3      138705
# 4      101004
#         ...
# 995    132483
# 996     42392
# 997     96914
# 998     60500
# 999    129949
# Name: Salary, Length: 1000, dtype: int64

# %%
# convert data in Salary column into array

salary = np.array(data[['Salary', 'Bonus %']])
print(f"{salary}, size: {np.shape(salary)}, type: {type(salary)}")
# Out:
# [[9.73080e+04 6.94500e+00]
#  [6.19330e+04 4.17000e+00]
#  [1.30590e+05 1.18580e+01]
#  ...
#  [9.69140e+04 1.42100e+00]
#  [6.05000e+04 1.19850e+01]
#  [1.29949e+05 1.01690e+01]], size: (1000, 2), type: <class 'numpy.ndarray'>

# %%
# to convert data in 'Salary' into array second method

salary1 = data['Salary'].values
salary1
# Out:
# array([ 97308,  61933, 130590, 138705, 101004, 115163,  65476,  45906,
#         95570, 139852,  63241, 102508, 112807, 109831,  41426,  59414,
#         90370, 111737, 132940,  81014,  64714, 100612,  90816, 125792,
#         97950,  37076,  37598, 122367, 124008,  79529, 118780,  88657,
#        122340, 119082,  95734,  85182, 142032,  57427,  36844, 122173,
#         99283,  66582, 121918,  73524, 145146,  88010, 114796,  66820,
#         93581, 113590,  94976,  41126,  49339,  40341,  83677, 102488,
#        130276,  64715,  72670,  66851,  48866, 106862,  58112,  35203,
#         77834,  61310, 125250,  51178,  84834, 100863,  84692, 118172,
#         54043,  90582,  62096, 104897, 131604, 107391, 114797, 115814,
#        137126,  47369,  35095, 148115,  83072, 100238, 103495, 144887,
#         64088,  51082,  91719, 128771, 119009, 111858, 130620,  43026,
#        142321, 140371, 100705,  77544,  48109,  61602, 103902, 136984,
# ...

# %%
data.head(10)  # print first 10 rows
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
data.tail(6)  # print last 6 rows
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 994     George   Male   6/21/2013         5:47 PM   98874    4.479
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 994              True             Marketing
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
# rename column

data = data.rename(columns={'Bonus %': 'Bonus', 'Last Login Time': 'last login'})
data.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login', 'Salary', 'Bonus',
#        'Senior Management', 'Team'],
#       dtype='object')

# %%
# to check number of entries in a particular column

lt = data['Gender'].value_counts()
lt
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
team_count = data['Team'].value_counts()
team_count
# Out:
# Team
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: count, dtype: int64

# %%
# to get complete info. about data set

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login         1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus              1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
data.describe()
# Out:
#               Salary        Bonus
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
# to convert data type of column

data['Senior Management'] = data['Senior Management'].astype("bool")
data['Start Date'] = pd.to_datetime(data['Start Date'])
data['Last Login'] = pd.to_datetime(data['Last Login'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login         1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus              1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
# to count number of null in data
data.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login             0
# Salary                 0
# Bonus                  0
# Senior Management      0
# Team                  43
# dtype: int64

# %%
.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
# to replace null value

data['First Name'] = data['First Name'].fillna("Unknown")
data['Gender'] = data['Gender'].fillna("Unknown")
data['Team'] = data['Team'].fillna("Unknown")

# %%
data.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login           0
# Salary               0
# Bonus                0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
# to remove a particular column

data2 = data.drop(['Last Login', 'Senior Management'], axis=1)
data2
# Out:
#     First Name   Gender Start Date  Salary   Bonus                  Team
# 0      Douglas     Male 1993-08-06   97308   6.945             Marketing
# 1       Thomas     Male 1996-03-31   61933   4.170               Unknown
# 2        Maria   Female 1993-04-23  130590  11.858               Finance
# 3        Jerry     Male 2005-03-04  138705   9.340               Finance
# 4        Larry     Male 1998-01-24  101004   1.389       Client Services
# ..         ...      ...        ...     ...     ...                   ...
# 995      Henry  Unknown 2014-11-23  132483  16.655          Distribution
# 996    Phillip     Male 1984-01-31   42392  19.675               Finance
# 997    Russell     Male 2013-05-20   96914   1.421               Product
# 998      Larry     Male 2013-04-20   60500  11.985  Business Development
# 999     Albert     Male 2012-05-15  129949  10.169                 Sales
#
# [1000 rows x 6 columns]

# %%
# to remove a particular row

data3 = data.drop([1,4,6],axis=0)
data3
# Out:
#     First Name   Gender Start Date          Last Login  Salary   Bonus  \
# 0      Douglas     Male 1993-08-06 2024-01-17 12:42:00   97308   6.945
# 2        Maria   Female 1993-04-23 2024-01-17 11:17:00  130590  11.858
# 3        Jerry     Male 2005-03-04 2024-01-17 13:00:00  138705   9.340
# 5       Dennis     Male 1987-04-18 2024-01-17 01:35:00  115163  10.125
# 7      Unknown   Female 2015-07-20 2024-01-17 10:43:00   45906  11.598
# ..         ...      ...        ...                 ...     ...     ...
# 995      Henry  Unknown 2014-11-23 2024-01-17 06:09:00  132483  16.655
# 996    Phillip     Male 1984-01-31 2024-01-17 06:30:00   42392  19.675
# 997    Russell     Male 2013-05-20 2024-01-17 12:39:00   96914   1.421
# 998      Larry     Male 2013-04-20 2024-01-17 16:45:00   60500  11.985
# 999     Albert     Male 2012-05-15 2024-01-17 18:24:00  129949  10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
# grouping of data

data1.groupby('Gender')[['Salary', 'Bonus']].sum()
# Out:
#           Salary     Bonus
# Gender
# Female  35266576  3914.525
# Male    33824386  3838.578

# %%
# slicing dataset

data1.iloc[0:6, 0:3]
# Out:
#   First Name  Gender Start Date
# 0    Douglas    Male 1993-08-06
# 2      Maria  Female 1993-04-23
# 3      Jerry    Male 2005-03-04
# 4      Larry    Male 1998-01-24
# 5     Dennis    Male 1987-04-18
# 6       Ruby  Female 1987-08-17

# %%
# to export data

data1.to_csv()
